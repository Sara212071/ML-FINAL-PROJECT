# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer, load_iris
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score
# %matplotlib inline
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier,IsolationForest
from sklearn.model_selection import train_test_split
from sklearn.covariance import EllipticEnvelope
from sklearn.neighbors import LocalOutlierFactor
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler,LabelEncoder
from imblearn.over_sampling import SMOTE,RandomOverSampler
from sklearn.ensemble import AdaBoostClassifier
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as imbPipeline

# %%
faulty = pd.read_csv('faults.csv')
faulty.head()
# read the dataset from csv
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    108  ...             0.8182           -0.2913
# ...

# %%
faulty.shape #get the shape of the dataset
# Out:
# (1941, 34)

# %%
faulty.isnull().sum() # find the sum of the nulls in the df
# Out:
# X_Minimum                0
# X_Maximum                0
# Y_Minimum                0
# Y_Maximum                0
# Pixels_Areas             0
# X_Perimeter              0
# Y_Perimeter              0
# Sum_of_Luminosity        0
# Minimum_of_Luminosity    0
# Maximum_of_Luminosity    0
# Length_of_Conveyer       0
# TypeOfSteel_A300         0
# TypeOfSteel_A400         0
# Steel_Plate_Thickness    0
# Edges_Index              0
# Empty_Index              0
# Square_Index             0
# Outside_X_Index          0
# Edges_X_Index            0
# Edges_Y_Index            0
# Outside_Global_Index     0
# LogOfAreas               0
# Log_X_Index              0
# Log_Y_Index              0
# Orientation_Index        0
# Luminosity_Index         0
# SigmoidOfAreas           0
# Pastry                   0
# Z_Scratch                0
# K_Scatch                 0
# Stains                   0
# Dirtiness                0
# Bumps                    0
# Other_Faults             0
# ...

# %%
faulty['All_faults'] = faulty[['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']].idxmax(axis=1)
#creating a new column called 'All_faults' in the faulty DataFrame, where each row is labeled with the type of fault

# %%
faulty.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Luminosity_Index  SigmoidOfAreas  Pastry  \
# 0                    108  ...           -0.2913          0.5822       1
# ...

# %%
faulty = faulty.drop(['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults'], axis=1) 
# deleting the columns after adding them to the all faults column

# %%
faulty
# Out:
#       X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0            42         50     270900     270944           267           17
# 1           645        651    2538079    2538108           108           10
# 2           829        835    1553913    1553931            71            8
# 3           853        860     369370     369415           176           13
# 4          1289       1306     498078     498335          2409           60
# ...         ...        ...        ...        ...           ...          ...
# 1936        249        277     325780     325796           273           54
# 1937        144        175     340581     340598           287           44
# 1938        145        174     386779     386794           292           40
# 1939        137        170     422497     422528           419           97
# 1940       1261       1281      87951      87967           103           26
#
# ...

# %%
faulty['All_faults'].replace('Pastry',1,inplace=True)
faulty['All_faults'].replace('Z_Scratch',2,inplace=True)
faulty['All_faults'].replace('K_Scatch',3,inplace=True)
faulty['All_faults'].replace('Stains',4,inplace=True)
faulty['All_faults'].replace('Dirtiness',5,inplace=True)
faulty['All_faults'].replace('Bumps',6,inplace=True)
faulty['All_faults'].replace('Other_Faults',7,inplace=True)
faulty.head()  # replacing the strings with ints to be able to work with it
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Edges_X_Index  Edges_Y_Index  \
# 0                    108  ...         0.4706         1.0000
# ...

# %%
faulty.dtypes # get the datatypes
# Out:
# X_Minimum                  int64
# X_Maximum                  int64
# Y_Minimum                  int64
# Y_Maximum                  int64
# Pixels_Areas               int64
# X_Perimeter                int64
# Y_Perimeter                int64
# Sum_of_Luminosity          int64
# Minimum_of_Luminosity      int64
# Maximum_of_Luminosity      int64
# Length_of_Conveyer         int64
# TypeOfSteel_A300           int64
# TypeOfSteel_A400           int64
# Steel_Plate_Thickness      int64
# Edges_Index              float64
# Empty_Index              float64
# Square_Index             float64
# Outside_X_Index          float64
# Edges_X_Index            float64
# Edges_Y_Index            float64
# Outside_Global_Index     float64
# LogOfAreas               float64
# Log_X_Index              float64
# Log_Y_Index              float64
# Orientation_Index        float64
# Luminosity_Index         float64
# SigmoidOfAreas           float64
# All_faults                 int64
# dtype: object

# %%
column_name = 'All_faults' 
value_counts = faulty[column_name].value_counts()
plt.figure(figsize=(10, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title(f'check unique at {column_name}')
plt.xlabel(column_name)
plt.ylabel('Count')
plt.show()
#check the number of each unqiue class at all faults column

# %%
 faulty.columns # get column names
# Out:
# Index(['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
#        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity',
#        'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer',
#        'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness',
#        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
#        'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas',
#        'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index',
#        'SigmoidOfAreas', 'All_faults'],
#       dtype='object')

# %%
faulty.duplicated().sum() #check for duplicates
# Out:
# 0

# %%
for column in faulty.columns:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(x=faulty[column])
    plt.title(f'Box Plot for {column}')
    plt.xlabel(column)
    plt.show() 
    #box plot for outliers

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor

xz = faulty.iloc[:, :-1]
yz = faulty['All_faults']

outlierDetector2 =  LocalOutlierFactor(n_neighbors=40)
result2=outlierDetector2.fit_predict(xz)
# split the df into xz(anything except target) and yz(target)uses the Local Outlier Factor algorithm (outlierDetector2)
#to predict whether each data point is an inlier or an outlier, storing the results in the result2 variable

# %%
Outliers=xz[result2==-1]
print("Number of detected outliers is " +str(len(Outliers)))
#This code identifies outliers using the Local Outlier Factor results and prints the count of detected outliers in the DataFrame xz
# Out:
# Number of detected outliers is 117

# %%
ax = yz[result2 != -1].value_counts().sort_index().plot(kind='bar', color=['red', 'blue', 'green', 'blueviolet', 'navy'],
                                                       title='Fault Categories After Local Outlier Factor', figsize=(8, 6))

ax.set_xlabel("Fault Category", fontsize=16)
ax.set_ylabel("Number of Instances", fontsize=14)
plt.show()
# visualize the distribution of fault categories after applying the Local Outlier Factor algorithm, using data from the DataFrame yz and the outlier results from result2

# %%
import pandas as pd

value_counts = yz.value_counts()


# Display the counts
print("Number of occurrences of each value in the 'All_faults' column:")
print(value_counts)
# number of occurences of each value
# Out:
# Number of occurrences of each value in the 'All_faults' column:
# 7    673
# 6    402
# 3    391
# 2    190
# 1    158
# 4     72
# 5     55
# Name: All_faults, dtype: int64

# %%
newXx = xz[result2 != -1]
newYy = yz[result2 != -1]

x_train, x_test, y_train, y_test = train_test_split(newXx, newYy, test_size=0.3, random_state=42)

# Split the dataset into training and testing sets after the outliers removed

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth = 20, min_samples_split=3, random_state=42)
rf.fit(x_train, y_train)

# Prediction on the test set
y_predef = rf.predict(x_test)

# Evaluate the model
acc = accuracy_score(y_predef, y_test)
print(f"Accuracy of the model: {acc:.4f} after outlier removal")
#using the rf model with hyper p after the outlier removal
# Out:
# Accuracy of the model: 0.7719 after outlier removal

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
class_names = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

cm = confusion_matrix(y_test, y_predef)


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Plot confusion matrix of rf after outlier removal

# %%
class_report = classification_report(y_test, y_predef)
print("Classification Report:\n", class_report)

#classification report
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.47      0.42      0.44        33
#            2       0.96      0.89      0.92        55
#            3       0.99      0.97      0.98       112
#            4       0.91      0.91      0.91        22
#            5       0.80      0.80      0.80        15
#            6       0.65      0.55      0.59       113
#            7       0.70      0.79      0.74       198
#
#     accuracy                           0.77       548
#    macro avg       0.78      0.76      0.77       548
# weighted avg       0.77      0.77      0.77       548

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


logreg = LogisticRegression(random_state=42, solver = 'liblinear')
logreg.fit(x_train, y_train)


y_predl = logreg.predict(x_test)

accuracy = accuracy_score(y_test, y_predl)
conf_matrix = confusion_matrix(y_test, y_predl)

print("Accuracy:", accuracy)


plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=logreg.classes_, yticklabels=logreg.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# this is after the outlier removal only and the confusion matrix is poor
# Out:
# Accuracy: 0.5693430656934306

# %%
class_report1 = classification_report(y_test, y_predl)
print("Classification Report:\n", class_report1)
#classfication report of the log
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        33
#            2       0.00      0.00      0.00        55
#            3       0.94      0.85      0.89       112
#            4       0.84      0.73      0.78        22
#            5       0.00      0.00      0.00        15
#            6       0.52      0.21      0.30       113
#            7       0.46      0.89      0.61       198
#
#     accuracy                           0.57       548
#    macro avg       0.40      0.38      0.37       548
# weighted avg       0.50      0.57      0.50       548
# C:\Users\20102\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
newYy.value_counts() 
#counts of every class in all_faults
# Out:
# 7    627
# 6    396
# 3    351
# 2    177
# 1    147
# 4     72
# 5     54
# Name: All_faults, dtype: int64

# %% [markdown]
# #
# oversample

# %%
oversample = SMOTE(random_state=42)
overX,overY=oversample.fit_resample(x_train, y_train) 
#using oversampling on the training data

# %% [markdown]
# yt_test,xt_test

# %%
overY.value_counts() # equal values in all the clases
# Out:
# 4    429
# 7    429
# 5    429
# 1    429
# 6    429
# 3    429
# 2    429
# Name: All_faults, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
overX_scaled = scaler.fit_transform(overX)
x_test_scaled = scaler.transform(x_test)


rfo_clf = RandomForestClassifier(n_estimators=100, max_depth=40, min_samples_split=3, random_state=42)
rfo_clf.fit(overX_scaled, overY)

# Make predictions on the standardized testing data
opy_pred = rfo_clf.predict(x_test_scaled)


cm = confusion_matrix(y_test, opy_pred, labels=rfo_clf.classes_)


disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rfo_clf.classes_)


fig, ax = plt.subplots(figsize=(10, 8))  # Adjust the width as needed
ax.grid(False)


disp.plot(ax=ax)

plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")

plt.show()
# using random forest where i used the scalar function in it was better in the confusion matrix in classes than before smote

# %%
class_report = classification_report(y_test, opy_pred)
print("Classification Report:\n", class_report)

# classification report for rf after smote
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.40      0.61      0.48        33
#            2       0.93      0.95      0.94        55
#            3       0.98      0.98      0.98       112
#            4       1.00      0.95      0.98        22
#            5       0.76      0.87      0.81        15
#            6       0.63      0.65      0.64       113
#            7       0.78      0.70      0.74       198
#
#     accuracy                           0.78       548
#    macro avg       0.78      0.81      0.80       548
# weighted avg       0.79      0.78      0.78       548

# %%
print("ACC of model: %.4f After SMOTE detection" % accuracy_score(y_test, opy_pred))
# accuracy of rf after smote
# Out:
# ACC of model: 0.7792 After SMOTE detection

# %%
# Calculate the learning curve
train_sizes, train_scores, test_scores = learning_curve(
    rfo_clf, overX_scaled, overY, train_sizes=np.linspace(0.1, 1.0, 10), cv=5, scoring='accuracy'
)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15)
plt.plot(train_sizes, test_mean, label='Test Accuracy', marker='o', markersize=5)  
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15)

plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for RandomForestClassifier')
plt.legend()
plt.grid()
plt.show()
# creating a learning curve of the rf after smote showing the traing and test accuracy

# %%
from mlxtend.evaluate import bias_variance_decomp
x_train_np = overX_scaled
y_train_np = overY.values
x_test_np = x_test_scaled
y_test_np = y_test.values


mse, bias, var = bias_variance_decomp(
    rfo_clf, x_train_np, y_train_np, x_test_np, y_test_np,
    loss='mse', num_rounds=20, random_seed=42
)

print("MSE:", mse)
print("Bias:", bias)
print("Variance:", var)
#Calculate the MSE variance and bias of the rf after smote
# Out:
# MSE: 3.177919708029197
# Bias: 2.4828193430656933
# Variance: 0.6951003649635037

# %%
overX_scaled.shape,overY.shape
# Out:
# ((3003, 27), (3003,))

# %% [markdown]
# #
# Testing LOG

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
overX_scaled = scaler.fit_transform(overX)
x_test_scaled = scaler.transform(x_test)

logreg_clf_scaled = LogisticRegression(random_state=42, max_iter=1000)
logreg_clf_scaled.fit(overX_scaled, overY)
predictions_scaled = logreg_clf_scaled.predict(x_test_scaled)

accuracy_scaled = accuracy_score(y_test, predictions_scaled)
print(f"Scaled Logistic Regression Accuracy: {accuracy_scaled}")
# Out:
# Scaled Logistic Regression Accuracy: 0.6806569343065694

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, predictions_scaled)


disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=logreg_clf_scaled.classes_)


fig, ax = plt.subplots(figsize=(8, 6))  
ax.grid(False)


disp.plot(ax=ax)


plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix for Logistic Regression Model")

# Show the plot
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    logreg_clf_scaled, overX_scaled, overY, train_sizes=np.linspace(0.1, 1.0, 10), cv=5, scoring='accuracy', n_jobs=-1
)


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)


plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15)
plt.plot(train_sizes, test_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15)

plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for Logistic Regression')
plt.legend()
plt.grid()
plt.show()
# creating a learning curve of the lg after smote showing the traing and test accuracy

# %% [markdown]
# #
# Testing BAG

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

bag_clf = BaggingClassifier(
    DecisionTreeClassifier(splitter="random", max_leaf_nodes=100, random_state=42),
    n_estimators=100, max_samples=1.0, bootstrap=True, n_jobs=-1, random_state=42)

bag_clf.fit(overX, overY)
y_pred_rDT = bag_clf.predict(x_test)

# %%
print ("Decision Tree (Bagging with random Splitter) = ", accuracy_score(y_test, y_pred_rDT))
# Out:
# Decision Tree (Bagging with random Splitter) =  0.7481751824817519

# %%
cm = confusion_matrix(y_test, y_pred_rDT)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=bag_clf.classes_)


fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the width and height as needed
ax.grid(False)


disp.plot(ax=ax)


plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve


train_sizes, train_scores, test_scores = learning_curve(
    bag_clf, overX, overY, train_sizes=np.linspace(0.1, 1.0, 10), cv=5, scoring='accuracy', n_jobs=-1
)


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)


plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15)
plt.plot(train_sizes, test_mean, label='Validation Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15)

plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for BaggingClassifier')
plt.legend()
plt.grid()
plt.show()
# creating a learning curve of the bg after smote showing the traing and test accuracy

# %% [markdown]
#  KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

scaler = StandardScaler()
overX_scaled = scaler.fit_transform(overX)
x_test_scaled = scaler.transform(x_test)

knn0_clf = KNeighborsClassifier(n_neighbors=3, metric='manhattan')
knn0_clf.fit(overX_scaled, overY)

# Make predictions on training and test data
oy_train_pred23 = knn0_clf.predict(overX_scaled)
oy_test_pred23 = knn0_clf.predict(x_test_scaled)


train_accuracy = accuracy_score(overY, oy_train_pred23)
test_accuracy = accuracy_score(y_test, oy_test_pred23)

print("KNeighborsClassifier Results:")
print("Training Accuracy: {:.2f}".format(train_accuracy))
print("Test Accuracy: {:.2f}".format(test_accuracy))

# standardize the features, and train a KNN classifier on the oversampled training data,
# Out:
# KNeighborsClassifier Results:
# Training Accuracy: 0.94
# Test Accuracy: 0.71

# %%
cm = confusion_matrix(y_test, oy_test_pred23, labels=knn0_clf.classes_)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=knn0_clf.classes_)

fig, ax = plt.subplots(figsize=(8, 6)) 
ax.grid(False)

disp.plot(ax=ax)

plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - KNeighborsClassifier")

plt.show()

#confusion matrix for the knn

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve


train_sizes, train_scores, test_scores = learning_curve(
    knn0_clf, overX_scaled, overY, train_sizes=np.linspace(0.1, 1.0, 10), cv=5, scoring='accuracy', n_jobs=-1
)


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)


plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15)
plt.plot(train_sizes, test_mean, label='Validation Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15)

plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for KNN')
plt.legend()
plt.grid()
plt.show()

# creating a learning curve of the knn after smote showing the traing and test accuracy

# %%
print("Classification Report - Test Data:")
print(classification_report(y_test, oy_test_pred23))
#classification report for the knn
# Out:
# Classification Report - Test Data:
#               precision    recall  f1-score   support
#
#            1       0.35      0.52      0.41        33
#            2       0.71      0.96      0.82        55
#            3       0.92      0.99      0.95       112
#            4       0.88      0.95      0.91        22
#            5       0.60      1.00      0.75        15
#            6       0.56      0.58      0.57       113
#            7       0.77      0.54      0.63       198
#
#     accuracy                           0.71       548
#    macro avg       0.68      0.79      0.72       548
# weighted avg       0.73      0.71      0.71       548

# %%
from mlxtend.evaluate import bias_variance_decomp
x_train_np = overX_scaled
oy_train_np = overY.values
x_test_np = x_test_scaled
oy_test_np = y_test.values

mse, bias, var = bias_variance_decomp(
    knn0_clf, x_train_np, oy_train_np, x_test_np, oy_test_np,
    loss='mse', num_rounds=20, random_seed=42
)


print("MSE:", mse)
print("Bias:", bias)
print("Variance:", var)
#calculate the mse , bias, variance
# Out:
# MSE: 4.143339416058395
# Bias: 2.776181569343066
# Variance: 1.3671578467153285

# %% [markdown]
#  SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
overX_scaled = scaler.fit_transform(overX)

svm_clf = SVC(C= 10, random_state=42, probability=True) 


svm_clf.fit(overX_scaled, overY)


predictions_svm = svm_clf.predict(x_test_scaled)


accuracy_svm = accuracy_score(y_test, predictions_svm)

print(f"SVM Accuracy: {accuracy_svm}")
# standardize the features, and train a SVM classifier on the oversampled training data,
# Out:
# SVM Accuracy: 0.7755474452554745

# %%
cm = confusion_matrix(y_test, predictions_svm)


disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svm_clf.classes_)


fig, ax = plt.subplots(figsize=(8, 6))  
ax.grid(False)


disp.plot(ax=ax)


plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix for SVM Classifier")

# Show the plot
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    svm_clf, overX_scaled, overY, train_sizes=np.linspace(0.1, 1.0, 10), cv=5, scoring='accuracy'
)


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)


plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15)
plt.plot(train_sizes, test_mean, label='Test Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15)

plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for SVM Classifier')
plt.legend()
plt.grid()
plt.show()
# creating a learning curve of the svm after smote showing the traing and test accuracy

# %%
print("\nClassification Report:")
print(classification_report(y_test, predictions_svm))
#classification report for the svm
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.54      0.64      0.58        33
#            2       0.81      0.91      0.85        55
#            3       0.95      0.97      0.96       112
#            4       0.91      0.95      0.93        22
#            5       0.87      0.87      0.87        15
#            6       0.64      0.66      0.65       113
#            7       0.77      0.69      0.73       198
#
#     accuracy                           0.78       548
#    macro avg       0.78      0.81      0.80       548
# weighted avg       0.78      0.78      0.77       548

# %%
from mlxtend.evaluate import bias_variance_decomp
x_train_np = overX_scaled
oy_train_np = overY.values
x_test_np = x_test_scaled
oy_test_np = y_test.values

mse, bias, var = bias_variance_decomp(
    svm_clf, x_train_np, oy_train_np, x_test_np, oy_test_np,
    loss='mse', num_rounds=20, random_seed=42
)


print("MSE:", mse)
print("Bias:", bias)
print("Variance:", var)
#calculate for the mse, bias, variance
# Out:
# MSE: 3.3278284671532843
# Bias: 2.2661633211678835
# Variance: 1.0616651459854014

# %% [markdown]
# #
# Testing Pipleline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'x_train', 'x_test', 'y_train', 'y_test' are your train and test data
# 'class_names' is the list of class names, e.g., ['Class 1', 'Class 2', ...]

# Create a pipeline with a scaler and a RandomForestClassifier
Pipe1 = Pipeline([('Scaler', StandardScaler()), ('model', RandomForestClassifier(n_estimators=100, random_state=42))])

# Fit the pipeline on the training data
Pipe1.fit(overX, overY)

# Predict using the pipeline
yf_pred = Pipe1.predict(x_test)

# Print accuracy
print("Accuracy of the model: %.4f with Pipeline" % accuracy_score(yf_pred, y_test))

# Calculate confusion matrix
cm = confusion_matrix(y_test, yf_pred)

# Plot confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy of the model: 0.7628 with Pipeline

# %% [markdown]
# svm_clf, rfo_clf,knn0_clf

# %%
from sklearn.ensemble import VotingClassifier

# Create a voting classifier
voting_clf = VotingClassifier(
    estimators=[
        ('svm', svm_clf),
        ('random_forest', rfo_clf),
        ('knn', knn0_clf)
    ],
    voting='hard' 
)


voting_clf.fit(overX_scaled, overY)


predictions_voting = voting_clf.predict(x_test_scaled)

accuracy_voting = accuracy_score(y_test, predictions_voting)
print(f"Voting Classifier Accuracy: {accuracy_voting}")
#Create a voting classifier, Train the voting classifier on the training data,Make predictions on the testing data, Evaluate the performance of the voting classifier
# Out:
# Voting Classifier Accuracy: 0.7609489051094891

# %%
classification_rep_voting = classification_report(y_test, predictions_voting)
print("Classification Report for Voting Classifier:")
print(classification_rep_voting) 
#classification report of voting
# Out:
# Classification Report for Voting Classifier:
#               precision    recall  f1-score   support
#
#            1       0.44      0.70      0.54        33
#            2       0.77      0.96      0.85        55
#            3       0.95      0.99      0.97       112
#            4       0.91      0.95      0.93        22
#            5       0.81      0.87      0.84        15
#            6       0.63      0.65      0.64       113
#            7       0.79      0.62      0.70       198
#
#     accuracy                           0.76       548
#    macro avg       0.76      0.82      0.78       548
# weighted avg       0.77      0.76      0.76       548

# %%
train_sizes, train_scores, test_scores = learning_curve(
    voting_clf, overX_scaled, overY, train_sizes=np.linspace(0.1, 1.0, 10), cv=5, scoring='accuracy'
)


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, label='Training Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.15)
plt.plot(train_sizes, test_mean, label='Test Accuracy', marker='o', markersize=5)
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.15)

plt.xlabel('Number of Training Samples')
plt.ylabel('Accuracy')
plt.title('Learning Curve for voting Classifier')
plt.legend()
plt.grid()
plt.show()
# creating a learning curve of the voting after smote showing the traing and test accuracy

# %%
from mlxtend.evaluate import bias_variance_decomp
x_train_np = overX_scaled
oy_train_np = overY.values
x_test_np = x_test_scaled
oy_test_np = y_test.values

mse, bias, var = bias_variance_decomp(
    voting_clf, x_train_np, oy_train_np, x_test_np, oy_test_np,
    loss='mse', num_rounds=20, random_seed=42
)


print("MSE:", mse)
print("Bias:", bias)
print("Variance:", var)

#calculate the mse, bias, variance for voting
# Out:
# MSE: 3.4479927007299267
# Bias: 2.4024635036496353
# Variance: 1.045529197080292
